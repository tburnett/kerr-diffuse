# %% [markdown]
# # Convert Kerr file(s) to FITS
# Adding the possibility of adding a related colunn from a new file
# Copy the file fermi:kerr/tobe_files/toby_exposure.npz

# %%
# %reset -f
# %run pylib/tools dark
from importlib import reload

# %%
from like3 import kerr_pixel_table as kpt_mod; reload(kpt_mod)
KerrPixelTable = kpt_mod.KerrPixelTable
pt = KerrPixelTable('files/kerr/toby_v4','files/kerr/toby_exposure', toring=True)
pt.to_fits(f'{pt.name}.fits')
# Out:
# Loaded columns ['diffuse', 'pointsources', 'extendedsources', 'sunmoon', 'counts', 'indices'] from files/kerr/toby_v4.npz
# Loaded columns ['exposure'] from files/kerr/toby_exposure.npz
# Wrote FITS file to files/kerr/toby_v4.fits

# %%
from astropy.io import fits
with fits.open('files/kerr/toby_v4.fits') as hdul:
    
    hdul.info()
    skymap = hdul[1]
    print(skymap.columns)
# Out:
# Filename: files/kerr/toby_v4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  SKYMAP        1 BinTableHDU     31   8241686R x 8C   [J, I, E, E, E, E, E, E]
#   2  BANDS         1 BinTableHDU     20   43R x 4C   [J, D, D, J]
# ColDefs(
#     name = 'PIX'; format = 'J'
#     name = 'CHANNEL'; format = 'I'
#     name = 'DIFFUSE'; format = 'E'
#     name = 'POINTSOURCES'; format = 'E'
#     name = 'EXTENDEDSOURCES'; format = 'E'
#     name = 'SUNMOON'; format = 'E'
#     name = 'COUNTS'; format = 'E'
#     name = 'EXPOSURE'; format = 'E'
# )
