# %% [markdown]
# # PixelTable fitting

# %%
# %run pylib/tools dark
from utilities.ipynb_docgen import show, show_date
from pylib.tools import np
from importlib import reload
import like3.pixel_table as pixel_table_mod; reload(pixel_table_mod)
PixelTable = pixel_table_mod.PixelTable
Band = pixel_table_mod.PixelTable.Band
show_date()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x78ca5c6f8910>

# %%
pixel_table = pt = PixelTable(root='files/kerr/Toby_v4.fits')
# Out:
# Loaded pixel table from "files/kerr/Toby_v4.fits":
#             42 bands Band(0, 4): PSF0@1.33 GeV nside 64 occ 1.001 ... Band(3, 11): PSF3@74.99 GeV nside 2048 occ 0.000
#             193,317,496 photons
#             8,240,918 pixels, order ring
