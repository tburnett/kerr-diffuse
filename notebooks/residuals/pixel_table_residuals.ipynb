# %% [markdown]
# # PixelTable residuals

# %%
# %reset -f
# %run setup_notebook.py
# %run pylib/tools dark date
from like3 import pixel_table as pt_mod; reload(pt_mod)
PixelTable = pt_mod.PixelTable
from like3.pixel_table import *
pixel_table = pt = PixelTable('files/kerr/toby_v4.fits')
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7b1b83f5d160>
# Loaded pixel table from "files/kerr/toby_v4.fits":
#             42 bands Band(0, 4): PSF0@1.33 GeV nside 64 occ 1.001 ... Band(3, 11): PSF3@74.99 GeV nside 2048 occ 0.000
#             193,317,496 photons
#             8,240,918 pixels, order ring

# %%
multi_residual_plotter(pt)

# %%
ResidualPlotter(pixel_table(2,1)).plots()
ResidualPlotter(pixel_table(2,4)).plots()

# %%
ResidualPlotter(pixel_table(3,5)).plots()

# %%
from utilities import export_notebook_to_markdown
export_notebook_to_markdown('notebooks/residuals/pixel_table_residuals', output_dir='docs')
# Out:
# ✅ Export complete: parsed 6 cells, wrote 10 segments to docs/notebooks/residuals/pixel_table_residuals.md
